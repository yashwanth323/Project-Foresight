# %% [markdown]
# # FORESIGHT | Forecast Model
# Train the SKU-level Random Forest regressor and forecast the next 30 days.

# %%
from src.forecast import train_forecast_model, forecast_next_days
# Run train_forecast_model(clean_df, '../model.pkl'), then forecast_next_days(clean_df, '../model.pkl', 30).
