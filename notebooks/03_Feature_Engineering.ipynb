# %% [markdown]
# # FORESIGHT | Feature Engineering
# Features include calendar effects, weekend indicator, 7-day lag and rolling demand mean.

# %%
from src.pipeline import clean_sales_data
# Inspect `day_of_week`, `month`, `is_weekend`, `lag_7`, and `rolling_mean_7` in the clean data set.
