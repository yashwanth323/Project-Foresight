# %% [markdown]
# # FORESIGHT | Baseline Model
# Compare the learned model against a 7-day moving-average baseline using MAPE.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/sales_clean.csv')
baseline = df['rolling_mean_7']
baseline.describe()
