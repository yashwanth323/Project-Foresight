# %% [markdown]
# # FORESIGHT | Data Cleaning
# Load a sales export, validate required fields, clean invalid rows, and generate time-series features.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
from src.pipeline import read_sales_file, clean_sales_data
raw = read_sales_file('../data/raw/demo_sales.csv')
clean = clean_sales_data(raw)
clean.head()
