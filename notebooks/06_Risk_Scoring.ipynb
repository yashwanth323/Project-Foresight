# %% [markdown]
# # FORESIGHT | Inventory Risk Scoring
# Turn forecasted demand and current stock into stockout/overstock classifications and recommended actions.

# %%
from src.risk import score_inventory_risk, recommendations
# risks = score_inventory_risk(forecasts); recommendations(risks)
